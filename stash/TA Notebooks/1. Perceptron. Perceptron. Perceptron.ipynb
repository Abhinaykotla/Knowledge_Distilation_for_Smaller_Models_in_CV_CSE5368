# %%
import pandas as pd
from sklearn.utils import shuffle
import numpy as np

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', names=['feat_0', 'feat_1', 'feat_2', 'feat_3', 'label'])
# df.columns = ['feat_0', 'feat_1', 'feat_2', 'feat_3', 'label']

# %%
df
# Out:
#      feat_0  feat_1  feat_2  feat_3           label
# 0       5.1     3.5     1.4     0.2     Iris-setosa
# 1       4.9     3.0     1.4     0.2     Iris-setosa
# 2       4.7     3.2     1.3     0.2     Iris-setosa
# 3       4.6     3.1     1.5     0.2     Iris-setosa
# 4       5.0     3.6     1.4     0.2     Iris-setosa
# ..      ...     ...     ...     ...             ...
# 145     6.7     3.0     5.2     2.3  Iris-virginica
# 146     6.3     2.5     5.0     1.9  Iris-virginica
# 147     6.5     3.0     5.2     2.0  Iris-virginica
# 148     6.2     3.4     5.4     2.3  Iris-virginica
# 149     5.9     3.0     5.1     1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
features = df[['feat_0', 'feat_1', 'feat_2', 'feat_3']].values
labels = df['label'].values

# %%
df['label'].value_counts()
# Out:
# label
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
def get_prediction(x, w):
  a = np.dot(x, w)
  return 1 if a > 0.0 else -1


np.random.seed(1)
n_epochs = 15
w = np.random.random(5)
eta = 0.001
n_data = len(labels)

for epoch_idx in range(n_epochs):
  n_accurate = 0
  for f, label in zip(features, labels):
    x = np.hstack([1, f])
    y = 1 if label == 'Iris-setosa' else -1
    y_pred = get_prediction(x, w)
    if y == y_pred:
      n_accurate += 1
    w = w + eta*(y-y_pred)*x
  print(f'After epoch {epoch_idx}: Accuracy {100*n_accurate/n_data:0.2f}% with weights {[round(w_i, 3) for w_i in w.tolist()]}')
# Out:
# After epoch 0: Accuracy 67.33% with weights [0.319, 0.138, -0.271, -0.115, 0.017]
# After epoch 1: Accuracy 96.00% with weights [0.319, 0.13, -0.266, -0.134, 0.01]
# After epoch 2: Accuracy 95.33% with weights [0.321, 0.134, -0.254, -0.149, 0.004]
# After epoch 3: Accuracy 96.67% with weights [0.323, 0.14, -0.243, -0.157, 0.0]
# After epoch 4: Accuracy 96.00% with weights [0.323, 0.136, -0.235, -0.171, -0.005]
# After epoch 5: Accuracy 96.67% with weights [0.325, 0.143, -0.223, -0.179, -0.008]
# After epoch 6: Accuracy 97.33% with weights [0.325, 0.144, -0.215, -0.188, -0.012]
# After epoch 7: Accuracy 97.33% with weights [0.325, 0.144, -0.208, -0.196, -0.015]
# After epoch 8: Accuracy 97.33% with weights [0.325, 0.142, -0.202, -0.205, -0.018]
# After epoch 9: Accuracy 98.00% with weights [0.327, 0.153, -0.191, -0.204, -0.018]
# After epoch 10: Accuracy 98.67% with weights [0.327, 0.153, -0.189, -0.207, -0.019]
# ...

# %%
np.random.random(5)
# Out:
# array([0.48053093, 0.65076365, 0.50555225, 0.58772215, 0.24064598])

# %%
np.zeros(5)
# Out:
# array([0., 0., 0., 0., 0.])
